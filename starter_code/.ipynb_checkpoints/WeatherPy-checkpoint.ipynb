# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests as req
import time
from scipy.stats import linregress
import random

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %%
# API Key for openweather disabled
api_key = "1453be9086f2afdefafaffd83b66b68e"

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create datafrome of random latitudes and longitudes from range and add columns to be appended 
data= pd.DataFrame(columns =['Lat',"Lng","City","Temperature","Humidity","Cloudiness","Wind Speed(mph)"])
lat = []
lng = []
for x in range(0,1200):
    lat.append(random.uniform(-90,91))
    lng.append(random.uniform(-181,181))
data['Lat']=lat
data['Lng']=lng
data.head()
# Out:
#          Lat         Lng City Temperature Humidity Cloudiness Wind Speed(mph)
# 0 -58.207960  148.889093  NaN         NaN      NaN        NaN             NaN
# 1   7.464857   10.466310  NaN         NaN      NaN        NaN             NaN
# 2  25.843876   70.549980  NaN         NaN      NaN        NaN             NaN
# 3 -15.709678 -123.890919  NaN         NaN      NaN        NaN             NaN
# 4  22.759304   24.078607  NaN         NaN      NaN        NaN             NaN

# %%
#find the cities related to the coordinates
cities =[]
for index, row in data.iterrows():
    city=citipy.nearest_city(row["Lat"],row["Lng"])
    cities.append(city.city_name)
data['City']=cities
data.head()
# Out:
#          Lat         Lng     City Temperature Humidity Cloudiness  \
# 0 -58.207960  148.889093   hobart         NaN      NaN        NaN
# 1   7.464857   10.466310   wukari         NaN      NaN        NaN
# 2  25.843876   70.549980   barmer         NaN      NaN        NaN
# 3 -15.709678 -123.890919  rikitea         NaN      NaN        NaN
# 4  22.759304   24.078607     jalu         NaN      NaN        NaN
#
#   Wind Speed(mph)
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
#Make sure there are at least 500 unique cities to test and remove duplicates
new_data = data.drop_duplicates("City",keep="first")
len(new_data)
# Out:
# 523

# %%
#create empty arrays to store the data for temperature, humidity, clouds, and wind speed 
temp = []
humidity =[]
clouds = []
wind = []

counter = 0
url = "https://api.openweathermap.org/data/2.5/weather?q="
units = "imperial"

#iterate through the rows to pull data from the api 
for index, row in new_data.iterrows():
    counter +=1
    city = row["City"]
    target_url = url+city+"&appid="+api_key+"&units="+units
    print("we are now on city number "+str(counter))
    print("The name of the city is "+row["City"])
    print(target_url)
    print("__________________________________________________________________________________________")
    info = req.get(target_url).json()
try :
    temp.append(info['main']['temp'])
except :
    humidity.append(info['main']['humidity'])
    clouds.append(info['clouds']['all'])
    wind.append(info['wind']['speed'])
    time.sleep(1)
#assign the values from the arrays to the data frame
new_data["Temperature"]=temp
new_data["Humidity"]=humidity
new_data["Clouds"]=clouds
new_data["Wind Speed"]=wind
# Out:
# we are now on city number 1
# The name of the city is hobart
# https://api.openweathermap.org/data/2.5/weather?q=hobart&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 2
# The name of the city is wukari
# https://api.openweathermap.org/data/2.5/weather?q=wukari&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 3
# The name of the city is barmer
# https://api.openweathermap.org/data/2.5/weather?q=barmer&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 4
# The name of the city is rikitea
# https://api.openweathermap.org/data/2.5/weather?q=rikitea&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 5
# The name of the city is jalu
# https://api.openweathermap.org/data/2.5/weather?q=jalu&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 6
# The name of the city is punta arenas
# https://api.openweathermap.org/data/2.5/weather?q=punta arenas&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 7
# The name of the city is cape town
# https://api.openweathermap.org/data/2.5/weather?q=cape town&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 8
# The name of the city is aklavik
# https://api.openweathermap.org/data/2.5/weather?q=aklavik&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 9
# The name of the city is puerto ayora
# https://api.openweathermap.org/data/2.5/weather?q=puerto ayora&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 10
# The name of the city is tuatapere
# https://api.openweathermap.org/data/2.5/weather?q=tuatapere&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 11
# The name of the city is norfolk
# https://api.openweathermap.org/data/2.5/weather?q=norfolk&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 12
# The name of the city is kangaatsiaq
# https://api.openweathermap.org/data/2.5/weather?q=kangaatsiaq&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 13
# The name of the city is chokurdakh
# https://api.openweathermap.org/data/2.5/weather?q=chokurdakh&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 14
# The name of the city is ushuaia
# https://api.openweathermap.org/data/2.5/weather?q=ushuaia&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 15
# The name of the city is alofi
# https://api.openweathermap.org/data/2.5/weather?q=alofi&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 16
# The name of the city is bubaque
# https://api.openweathermap.org/data/2.5/weather?q=bubaque&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 17
# The name of the city is taoudenni
# https://api.openweathermap.org/data/2.5/weather?q=taoudenni&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 18
# The name of the city is saint-philippe
# https://api.openweathermap.org/data/2.5/weather?q=saint-philippe&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 19
# The name of the city is flinders
# https://api.openweathermap.org/data/2.5/weather?q=flinders&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 20
# The name of the city is bluff
# https://api.openweathermap.org/data/2.5/weather?q=bluff&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 21
# The name of the city is cap malheureux
# https://api.openweathermap.org/data/2.5/weather?q=cap malheureux&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 22
# The name of the city is grindavik
# https://api.openweathermap.org/data/2.5/weather?q=grindavik&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 23
# The name of the city is grand gaube
# https://api.openweathermap.org/data/2.5/weather?q=grand gaube&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 24
# The name of the city is san patricio
# https://api.openweathermap.org/data/2.5/weather?q=san patricio&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 25
# The name of the city is shaunavon
# https://api.openweathermap.org/data/2.5/weather?q=shaunavon&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 26
# The name of the city is arraial do cabo
# https://api.openweathermap.org/data/2.5/weather?q=arraial do cabo&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 27
# The name of the city is kruisfontein
# https://api.openweathermap.org/data/2.5/weather?q=kruisfontein&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 28
# The name of the city is dzhusaly
# https://api.openweathermap.org/data/2.5/weather?q=dzhusaly&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 29
# The name of the city is victoria
# https://api.openweathermap.org/data/2.5/weather?q=victoria&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 30
# The name of the city is vestmannaeyjar
# https://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 31
# The name of the city is havelock
# https://api.openweathermap.org/data/2.5/weather?q=havelock&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 32
# The name of the city is saskylakh
# https://api.openweathermap.org/data/2.5/weather?q=saskylakh&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 33
# The name of the city is kaitangata
# https://api.openweathermap.org/data/2.5/weather?q=kaitangata&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 34
# The name of the city is torbay
# https://api.openweathermap.org/data/2.5/weather?q=torbay&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 35
# The name of the city is hilo
# https://api.openweathermap.org/data/2.5/weather?q=hilo&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 36
# The name of the city is nkhata bay
# https://api.openweathermap.org/data/2.5/weather?q=nkhata bay&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 37
# The name of the city is san isidro
# https://api.openweathermap.org/data/2.5/weather?q=san isidro&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 38
# The name of the city is mandan
# https://api.openweathermap.org/data/2.5/weather?q=mandan&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 39
# The name of the city is tawzar
# https://api.openweathermap.org/data/2.5/weather?q=tawzar&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 40
# The name of the city is boende
# https://api.openweathermap.org/data/2.5/weather?q=boende&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 41
# The name of the city is caravelas
# https://api.openweathermap.org/data/2.5/weather?q=caravelas&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 42
# The name of the city is hermanus
# https://api.openweathermap.org/data/2.5/weather?q=hermanus&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 43
# The name of the city is champerico
# https://api.openweathermap.org/data/2.5/weather?q=champerico&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 44
# The name of the city is kulhudhuffushi
# https://api.openweathermap.org/data/2.5/weather?q=kulhudhuffushi&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 45
# The name of the city is qaanaaq
# https://api.openweathermap.org/data/2.5/weather?q=qaanaaq&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 46
# The name of the city is chuy
# https://api.openweathermap.org/data/2.5/weather?q=chuy&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 47
# The name of the city is taolanaro
# https://api.openweathermap.org/data/2.5/weather?q=taolanaro&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 48
# The name of the city is tutoia
# https://api.openweathermap.org/data/2.5/weather?q=tutoia&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 49
# The name of the city is avarua
# https://api.openweathermap.org/data/2.5/weather?q=avarua&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 50
# The name of the city is nikolskoye
# https://api.openweathermap.org/data/2.5/weather?q=nikolskoye&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 51
# The name of the city is butaritari
# https://api.openweathermap.org/data/2.5/weather?q=butaritari&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 52
# The name of the city is atuona
# https://api.openweathermap.org/data/2.5/weather?q=atuona&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 53
# The name of the city is kapaa
# https://api.openweathermap.org/data/2.5/weather?q=kapaa&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 54
# The name of the city is mecca
# https://api.openweathermap.org/data/2.5/weather?q=mecca&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 55
# The name of the city is marabba
# https://api.openweathermap.org/data/2.5/weather?q=marabba&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 56
# The name of the city is rawson
# https://api.openweathermap.org/data/2.5/weather?q=rawson&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 57
# The name of the city is jizan
# https://api.openweathermap.org/data/2.5/weather?q=jizan&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 58
# The name of the city is yellowknife
# https://api.openweathermap.org/data/2.5/weather?q=yellowknife&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 59
# The name of the city is barentsburg
# https://api.openweathermap.org/data/2.5/weather?q=barentsburg&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 60
# The name of the city is san policarpo
# https://api.openweathermap.org/data/2.5/weather?q=san policarpo&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 61
# The name of the city is fortuna
# https://api.openweathermap.org/data/2.5/weather?q=fortuna&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 62
# The name of the city is gamba
# https://api.openweathermap.org/data/2.5/weather?q=gamba&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 63
# The name of the city is tuktoyaktuk
# https://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 64
# The name of the city is port alfred
# https://api.openweathermap.org/data/2.5/weather?q=port alfred&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 65
# The name of the city is upernavik
# https://api.openweathermap.org/data/2.5/weather?q=upernavik&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 66
# The name of the city is busselton
# https://api.openweathermap.org/data/2.5/weather?q=busselton&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 67
# The name of the city is ostrovnoy
# https://api.openweathermap.org/data/2.5/weather?q=ostrovnoy&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 68
# The name of the city is salym
# https://api.openweathermap.org/data/2.5/weather?q=salym&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 69
# The name of the city is longyearbyen
# https://api.openweathermap.org/data/2.5/weather?q=longyearbyen&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 70
# The name of the city is ribeira grande
# https://api.openweathermap.org/data/2.5/weather?q=ribeira grande&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 71
# The name of the city is jamestown
# https://api.openweathermap.org/data/2.5/weather?q=jamestown&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 72
# The name of the city is waipawa
# https://api.openweathermap.org/data/2.5/weather?q=waipawa&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 73
# The name of the city is ovalle
# https://api.openweathermap.org/data/2.5/weather?q=ovalle&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 74
# The name of the city is mahebourg
# https://api.openweathermap.org/data/2.5/weather?q=mahebourg&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 75
# The name of the city is ryotsu
# https://api.openweathermap.org/data/2.5/weather?q=ryotsu&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 76
# The name of the city is souillac
# https://api.openweathermap.org/data/2.5/weather?q=souillac&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 77
# The name of the city is albany
# https://api.openweathermap.org/data/2.5/weather?q=albany&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 78
# The name of the city is camacha
# https://api.openweathermap.org/data/2.5/weather?q=camacha&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 79
# The name of the city is asau
# https://api.openweathermap.org/data/2.5/weather?q=asau&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 80
# The name of the city is hasaki
# https://api.openweathermap.org/data/2.5/weather?q=hasaki&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 81
# The name of the city is ngukurr
# https://api.openweathermap.org/data/2.5/weather?q=ngukurr&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 82
# The name of the city is georgetown
# https://api.openweathermap.org/data/2.5/weather?q=georgetown&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 83
# The name of the city is dudinka
# https://api.openweathermap.org/data/2.5/weather?q=dudinka&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 84
# The name of the city is faanui
# https://api.openweathermap.org/data/2.5/weather?q=faanui&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 85
# The name of the city is zhigansk
# https://api.openweathermap.org/data/2.5/weather?q=zhigansk&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 86
# The name of the city is new norfolk
# https://api.openweathermap.org/data/2.5/weather?q=new norfolk&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 87
# The name of the city is mataura
# https://api.openweathermap.org/data/2.5/weather?q=mataura&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 88
# The name of the city is pisco
# https://api.openweathermap.org/data/2.5/weather?q=pisco&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 89
# The name of the city is airai
# https://api.openweathermap.org/data/2.5/weather?q=airai&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 90
# The name of the city is tasiilaq
# https://api.openweathermap.org/data/2.5/weather?q=tasiilaq&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 91
# The name of the city is sidi ali
# https://api.openweathermap.org/data/2.5/weather?q=sidi ali&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 92
# The name of the city is kutum
# https://api.openweathermap.org/data/2.5/weather?q=kutum&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 93
# The name of the city is olinda
# https://api.openweathermap.org/data/2.5/weather?q=olinda&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 94
# The name of the city is cayenne
# https://api.openweathermap.org/data/2.5/weather?q=cayenne&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 95
# The name of the city is lompoc
# https://api.openweathermap.org/data/2.5/weather?q=lompoc&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 96
# The name of the city is haines junction
# https://api.openweathermap.org/data/2.5/weather?q=haines junction&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 97
# The name of the city is baykit
# https://api.openweathermap.org/data/2.5/weather?q=baykit&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 98
# The name of the city is roebourne
# https://api.openweathermap.org/data/2.5/weather?q=roebourne&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 99
# The name of the city is nishihara
# https://api.openweathermap.org/data/2.5/weather?q=nishihara&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 100
# The name of the city is berlevag
# https://api.openweathermap.org/data/2.5/weather?q=berlevag&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 101
# The name of the city is mount isa
# https://api.openweathermap.org/data/2.5/weather?q=mount isa&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 102
# The name of the city is rehoboth
# https://api.openweathermap.org/data/2.5/weather?q=rehoboth&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 103
# The name of the city is hithadhoo
# https://api.openweathermap.org/data/2.5/weather?q=hithadhoo&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 104
# The name of the city is esperance
# https://api.openweathermap.org/data/2.5/weather?q=esperance&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 105
# The name of the city is geraldton
# https://api.openweathermap.org/data/2.5/weather?q=geraldton&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 106
# The name of the city is manaure
# https://api.openweathermap.org/data/2.5/weather?q=manaure&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 107
# The name of the city is ratnapura
# https://api.openweathermap.org/data/2.5/weather?q=ratnapura&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 108
# The name of the city is calama
# https://api.openweathermap.org/data/2.5/weather?q=calama&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 109
# The name of the city is marzuq
# https://api.openweathermap.org/data/2.5/weather?q=marzuq&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 110
# The name of the city is dikson
# https://api.openweathermap.org/data/2.5/weather?q=dikson&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 111
# The name of the city is bantogon
# https://api.openweathermap.org/data/2.5/weather?q=bantogon&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 112
# The name of the city is alice springs
# https://api.openweathermap.org/data/2.5/weather?q=alice springs&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 113
# The name of the city is nanortalik
# https://api.openweathermap.org/data/2.5/weather?q=nanortalik&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 114
# The name of the city is kokopo
# https://api.openweathermap.org/data/2.5/weather?q=kokopo&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 115
# The name of the city is sola
# https://api.openweathermap.org/data/2.5/weather?q=sola&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 116
# The name of the city is yumen
# https://api.openweathermap.org/data/2.5/weather?q=yumen&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 117
# The name of the city is poum
# https://api.openweathermap.org/data/2.5/weather?q=poum&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 118
# The name of the city is bambous virieux
# https://api.openweathermap.org/data/2.5/weather?q=bambous virieux&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 119
# The name of the city is kathmandu
# https://api.openweathermap.org/data/2.5/weather?q=kathmandu&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 120
# The name of the city is ishigaki
# https://api.openweathermap.org/data/2.5/weather?q=ishigaki&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 121
# The name of the city is tiksi
# https://api.openweathermap.org/data/2.5/weather?q=tiksi&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 122
# The name of the city is grand river south east
# https://api.openweathermap.org/data/2.5/weather?q=grand river south east&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 123
# The name of the city is cidreira
# https://api.openweathermap.org/data/2.5/weather?q=cidreira&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 124
# The name of the city is ancud
# https://api.openweathermap.org/data/2.5/weather?q=ancud&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 125
# The name of the city is vaini
# https://api.openweathermap.org/data/2.5/weather?q=vaini&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 126
# The name of the city is mbandaka
# https://api.openweathermap.org/data/2.5/weather?q=mbandaka&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 127
# The name of the city is svetlogorsk
# https://api.openweathermap.org/data/2.5/weather?q=svetlogorsk&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 128
# The name of the city is inhambane
# https://api.openweathermap.org/data/2.5/weather?q=inhambane&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 129
# The name of the city is bonavista
# https://api.openweathermap.org/data/2.5/weather?q=bonavista&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 130
# The name of the city is leh
# https://api.openweathermap.org/data/2.5/weather?q=leh&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 131
# The name of the city is labuhan
# https://api.openweathermap.org/data/2.5/weather?q=labuhan&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 132
# The name of the city is waddan
# https://api.openweathermap.org/data/2.5/weather?q=waddan&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 133
# The name of the city is port-gentil
# https://api.openweathermap.org/data/2.5/weather?q=port-gentil&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 134
# The name of the city is staryy oskol
# https://api.openweathermap.org/data/2.5/weather?q=staryy oskol&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 135
# The name of the city is la ronge
# https://api.openweathermap.org/data/2.5/weather?q=la ronge&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 136
# The name of the city is sao jose da coroa grande
# https://api.openweathermap.org/data/2.5/weather?q=sao jose da coroa grande&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 137
# The name of the city is illoqqortoormiut
# https://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 138
# The name of the city is palabuhanratu
# https://api.openweathermap.org/data/2.5/weather?q=palabuhanratu&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 139
# The name of the city is fort nelson
# https://api.openweathermap.org/data/2.5/weather?q=fort nelson&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 140
# The name of the city is port elizabeth
# https://api.openweathermap.org/data/2.5/weather?q=port elizabeth&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 141
# The name of the city is bredasdorp
# https://api.openweathermap.org/data/2.5/weather?q=bredasdorp&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 142
# The name of the city is muros
# https://api.openweathermap.org/data/2.5/weather?q=muros&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 143
# The name of the city is capao bonito
# https://api.openweathermap.org/data/2.5/weather?q=capao bonito&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 144
# The name of the city is vysokogornyy
# https://api.openweathermap.org/data/2.5/weather?q=vysokogornyy&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 145
# The name of the city is jumla
# https://api.openweathermap.org/data/2.5/weather?q=jumla&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 146
# The name of the city is turukhansk
# https://api.openweathermap.org/data/2.5/weather?q=turukhansk&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 147
# The name of the city is riberalta
# https://api.openweathermap.org/data/2.5/weather?q=riberalta&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 148
# The name of the city is fort frances
# https://api.openweathermap.org/data/2.5/weather?q=fort frances&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 149
# The name of the city is syntul
# https://api.openweathermap.org/data/2.5/weather?q=syntul&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 150
# The name of the city is talnakh
# https://api.openweathermap.org/data/2.5/weather?q=talnakh&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 151
# The name of the city is lokosovo
# https://api.openweathermap.org/data/2.5/weather?q=lokosovo&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 152
# The name of the city is lebu
# https://api.openweathermap.org/data/2.5/weather?q=lebu&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 153
# The name of the city is afsin
# https://api.openweathermap.org/data/2.5/weather?q=afsin&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 154
# The name of the city is vaitupu
# https://api.openweathermap.org/data/2.5/weather?q=vaitupu&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 155
# The name of the city is adolfo lopez mateos
# https://api.openweathermap.org/data/2.5/weather?q=adolfo lopez mateos&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 156
# The name of the city is eldikan
# https://api.openweathermap.org/data/2.5/weather?q=eldikan&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 157
# The name of the city is kerouane
# https://api.openweathermap.org/data/2.5/weather?q=kerouane&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 158
# The name of the city is lolua
# https://api.openweathermap.org/data/2.5/weather?q=lolua&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 159
# The name of the city is portland
# https://api.openweathermap.org/data/2.5/weather?q=portland&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 160
# The name of the city is maniitsoq
# https://api.openweathermap.org/data/2.5/weather?q=maniitsoq&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 161
# The name of the city is moron
# https://api.openweathermap.org/data/2.5/weather?q=moron&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 162
# The name of the city is sakakah
# https://api.openweathermap.org/data/2.5/weather?q=sakakah&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 163
# The name of the city is pacific grove
# https://api.openweathermap.org/data/2.5/weather?q=pacific grove&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 164
# The name of the city is iqaluit
# https://api.openweathermap.org/data/2.5/weather?q=iqaluit&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 165
# The name of the city is dembi dolo
# https://api.openweathermap.org/data/2.5/weather?q=dembi dolo&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 166
# The name of the city is pinsk
# https://api.openweathermap.org/data/2.5/weather?q=pinsk&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 167
# The name of the city is vila franca do campo
# https://api.openweathermap.org/data/2.5/weather?q=vila franca do campo&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 168
# The name of the city is rorvik
# https://api.openweathermap.org/data/2.5/weather?q=rorvik&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 169
# The name of the city is mezen
# https://api.openweathermap.org/data/2.5/weather?q=mezen&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 170
# The name of the city is bengkulu
# https://api.openweathermap.org/data/2.5/weather?q=bengkulu&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 171
# The name of the city is cabinda
# https://api.openweathermap.org/data/2.5/weather?q=cabinda&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 172
# The name of the city is atambua
# https://api.openweathermap.org/data/2.5/weather?q=atambua&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 173
# The name of the city is beringovskiy
# https://api.openweathermap.org/data/2.5/weather?q=beringovskiy&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 174
# The name of the city is saint-ambroise
# https://api.openweathermap.org/data/2.5/weather?q=saint-ambroise&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 175
# The name of the city is sukhobezvodnoye
# https://api.openweathermap.org/data/2.5/weather?q=sukhobezvodnoye&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 176
# The name of the city is ca mau
# https://api.openweathermap.org/data/2.5/weather?q=ca mau&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 177
# The name of the city is palora
# https://api.openweathermap.org/data/2.5/weather?q=palora&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 178
# The name of the city is kodiak
# https://api.openweathermap.org/data/2.5/weather?q=kodiak&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 179
# The name of the city is veraval
# https://api.openweathermap.org/data/2.5/weather?q=veraval&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 180
# The name of the city is nouadhibou
# ...
# we are now on city number 467
# The name of the city is severo-kurilsk
# https://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 468
# The name of the city is lambari
# https://api.openweathermap.org/data/2.5/weather?q=lambari&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 469
# The name of the city is tabou
# https://api.openweathermap.org/data/2.5/weather?q=tabou&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 470
# The name of the city is aranda de duero
# https://api.openweathermap.org/data/2.5/weather?q=aranda de duero&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 471
# The name of the city is olivenza
# https://api.openweathermap.org/data/2.5/weather?q=olivenza&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 472
# The name of the city is plettenberg bay
# https://api.openweathermap.org/data/2.5/weather?q=plettenberg bay&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 473
# The name of the city is yuancheng
# https://api.openweathermap.org/data/2.5/weather?q=yuancheng&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 474
# The name of the city is inuvik
# https://api.openweathermap.org/data/2.5/weather?q=inuvik&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 475
# The name of the city is gogosari
# https://api.openweathermap.org/data/2.5/weather?q=gogosari&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 476
# The name of the city is hurghada
# https://api.openweathermap.org/data/2.5/weather?q=hurghada&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 477
# The name of the city is hokitika
# https://api.openweathermap.org/data/2.5/weather?q=hokitika&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 478
# The name of the city is nizwa
# https://api.openweathermap.org/data/2.5/weather?q=nizwa&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 479
# The name of the city is honningsvag
# https://api.openweathermap.org/data/2.5/weather?q=honningsvag&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 480
# The name of the city is pultusk
# https://api.openweathermap.org/data/2.5/weather?q=pultusk&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 481
# The name of the city is hukuntsi
# https://api.openweathermap.org/data/2.5/weather?q=hukuntsi&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 482
# The name of the city is karratha
# https://api.openweathermap.org/data/2.5/weather?q=karratha&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 483
# The name of the city is puro
# https://api.openweathermap.org/data/2.5/weather?q=puro&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 484
# The name of the city is beboto
# https://api.openweathermap.org/data/2.5/weather?q=beboto&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 485
# The name of the city is saint anthony
# https://api.openweathermap.org/data/2.5/weather?q=saint anthony&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 486
# The name of the city is reconquista
# https://api.openweathermap.org/data/2.5/weather?q=reconquista&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 487
# The name of the city is ponta delgada
# https://api.openweathermap.org/data/2.5/weather?q=ponta delgada&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 488
# The name of the city is mattru
# https://api.openweathermap.org/data/2.5/weather?q=mattru&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 489
# The name of the city is ketchikan
# https://api.openweathermap.org/data/2.5/weather?q=ketchikan&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 490
# The name of the city is nizhneyansk
# https://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 491
# The name of the city is riyadh
# https://api.openweathermap.org/data/2.5/weather?q=riyadh&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 492
# The name of the city is tubruq
# https://api.openweathermap.org/data/2.5/weather?q=tubruq&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 493
# The name of the city is mandalgovi
# https://api.openweathermap.org/data/2.5/weather?q=mandalgovi&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 494
# The name of the city is mishelevka
# https://api.openweathermap.org/data/2.5/weather?q=mishelevka&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 495
# The name of the city is iquique
# https://api.openweathermap.org/data/2.5/weather?q=iquique&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 496
# The name of the city is miri
# https://api.openweathermap.org/data/2.5/weather?q=miri&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 497
# The name of the city is bayir
# https://api.openweathermap.org/data/2.5/weather?q=bayir&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 498
# The name of the city is sibolga
# https://api.openweathermap.org/data/2.5/weather?q=sibolga&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 499
# The name of the city is whitecourt
# https://api.openweathermap.org/data/2.5/weather?q=whitecourt&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 500
# The name of the city is sentyabrskiy
# https://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 501
# The name of the city is aswan
# https://api.openweathermap.org/data/2.5/weather?q=aswan&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 502
# The name of the city is carutapera
# https://api.openweathermap.org/data/2.5/weather?q=carutapera&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 503
# The name of the city is saravan
# https://api.openweathermap.org/data/2.5/weather?q=saravan&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 504
# The name of the city is mikuni
# https://api.openweathermap.org/data/2.5/weather?q=mikuni&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 505
# The name of the city is pulo
# https://api.openweathermap.org/data/2.5/weather?q=pulo&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 506
# The name of the city is ormara
# https://api.openweathermap.org/data/2.5/weather?q=ormara&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 507
# The name of the city is luderitz
# https://api.openweathermap.org/data/2.5/weather?q=luderitz&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 508
# The name of the city is whitianga
# https://api.openweathermap.org/data/2.5/weather?q=whitianga&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 509
# The name of the city is acari
# https://api.openweathermap.org/data/2.5/weather?q=acari&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 510
# The name of the city is samalaeulu
# https://api.openweathermap.org/data/2.5/weather?q=samalaeulu&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 511
# The name of the city is sur
# https://api.openweathermap.org/data/2.5/weather?q=sur&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 512
# The name of the city is calamar
# https://api.openweathermap.org/data/2.5/weather?q=calamar&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 513
# The name of the city is bhum
# https://api.openweathermap.org/data/2.5/weather?q=bhum&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 514
# The name of the city is manthani
# https://api.openweathermap.org/data/2.5/weather?q=manthani&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 515
# The name of the city is panama city
# https://api.openweathermap.org/data/2.5/weather?q=panama city&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 516
# The name of the city is son la
# https://api.openweathermap.org/data/2.5/weather?q=son la&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 517
# The name of the city is marienburg
# https://api.openweathermap.org/data/2.5/weather?q=marienburg&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 518
# The name of the city is varkkallai
# https://api.openweathermap.org/data/2.5/weather?q=varkkallai&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 519
# The name of the city is fayaoue
# https://api.openweathermap.org/data/2.5/weather?q=fayaoue&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 520
# The name of the city is mocuba
# https://api.openweathermap.org/data/2.5/weather?q=mocuba&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 521
# The name of the city is hervey bay
# https://api.openweathermap.org/data/2.5/weather?q=hervey bay&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 522
# The name of the city is trincomalee
# https://api.openweathermap.org/data/2.5/weather?q=trincomalee&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# we are now on city number 523
# The name of the city is sunamganj
# https://api.openweathermap.org/data/2.5/weather?q=sunamganj&appid=1453be9086f2afdefafaffd83b66b68e&units=imperial
# __________________________________________________________________________________________
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-439e39095a56> in <module>
#      21 try :
# ---> 22     temp.append(info['main']['temp'])
#      23 except :
#
# KeyError: 'main'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-439e39095a56> in <module>
#      22     temp.append(info['main']['temp'])
#      23 except :
# ---> 24     humidity.append(info['main']['humidity'])
#      25     clouds.append(info['clouds']['all'])
#      26     wind.append(info['wind']['speed'])
#
# KeyError: 'main'

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
